# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]   
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng" : city_lng,
                          "Max Temp" : city_max_temp,
                          "Humidity" : city_humidity,
                          "Cloudiness" : city_clouds,
                          "Wind Speed" : city_wind,
                          "Country" : city_country,
                          "Current Description" : city_description})
    
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 1 | biak
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | uray
# Processing Record 5 of Set 1 | cabo san lucas
# Processing Record 6 of Set 1 | arlit
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | urubamba
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | cockburn town
# Processing Record 13 of Set 1 | ancud
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | arkhipo-osipovka
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | chemal
# Processing Record 21 of Set 1 | deputatskiy
# Processing Record 22 of Set 1 | esna
# Processing Record 23 of Set 1 | tarko-sale
# Processing Record 24 of Set 1 | yulara
# Processing Record 25 of Set 1 | shimoda
# Processing Record 26 of Set 1 | campos belos
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | teguldet
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | licata
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | florida
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | husavik
# Processing Record 35 of Set 1 | mahebourg
# Processing Record 36 of Set 1 | harper
# Processing Record 37 of Set 1 | ust-kut
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | rengasdengklok
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | san patricio
# Processing Record 44 of Set 1 | charters towers
# Processing Record 45 of Set 1 | marsabit
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | bud
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | yeppoon
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | mingaora
# Processing Record 5 of Set 2 | talaya
# Processing Record 6 of Set 2 | vastervik
# City not found. Skipping...
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | sistranda
# Processing Record 12 of Set 2 | krasnoselkup
# Processing Record 13 of Set 2 | maningrida
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | ilulissat
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | sao sebastiao
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | adrar
# Processing Record 21 of Set 2 | jawhar
# Processing Record 22 of Set 2 | poum
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | pasighat
# Processing Record 25 of Set 2 | kloulklubed
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | pangkalanbuun
# Processing Record 32 of Set 2 | ulaanbaatar
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | aranos
# Processing Record 35 of Set 2 | khandyga
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | hobyo
# Processing Record 38 of Set 2 | volchikha
# Processing Record 39 of Set 2 | santiago del estero
# Processing Record 40 of Set 2 | yakeshi
# Processing Record 41 of Set 2 | olafsvik
# Processing Record 42 of Set 2 | natal
# Processing Record 43 of Set 2 | cordoba
# Processing Record 44 of Set 2 | singaraja
# Processing Record 45 of Set 2 | douglas
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | chokurdakh
# Processing Record 48 of Set 2 | cap-aux-meules
# Processing Record 49 of Set 2 | otradnoye
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | sao filipe
# Processing Record 2 of Set 3 | sorland
# Processing Record 3 of Set 3 | general roca
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | victoria
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | okha
# Processing Record 9 of Set 3 | san francisco
# Processing Record 10 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 11 of Set 3 | mbanza-ngungu
# Processing Record 12 of Set 3 | moose factory
# Processing Record 13 of Set 3 | sabang
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 3 | punta arenas
# Processing Record 17 of Set 3 | kununurra
# Processing Record 18 of Set 3 | santa rosa
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | tessalit
# Processing Record 21 of Set 3 | hilo
# Processing Record 22 of Set 3 | nabire
# Processing Record 23 of Set 3 | bilibino
# Processing Record 24 of Set 3 | urengoy
# Processing Record 25 of Set 3 | srednekolymsk
# Processing Record 26 of Set 3 | korla
# Processing Record 27 of Set 3 | ovsyanka
# Processing Record 28 of Set 3 | san juan de la maguana
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | huarmey
# Processing Record 31 of Set 3 | menongue
# Processing Record 32 of Set 3 | oranjemund
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | monte alegre
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | myskhako
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | provideniya
# Processing Record 39 of Set 3 | conceicao da barra
# Processing Record 40 of Set 3 | itapua poty
# City not found. Skipping...
# Processing Record 41 of Set 3 | agutaya
# Processing Record 42 of Set 3 | puerto escondido
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | flinders
# Processing Record 45 of Set 3 | geraldton
# Processing Record 46 of Set 3 | plattsburgh
# Processing Record 47 of Set 3 | codajas
# Processing Record 48 of Set 3 | lovosice
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 50 of Set 3 | meulaboh
# Processing Record 1 of Set 4 | westport
# Processing Record 2 of Set 4 | puerto colombia
# Processing Record 3 of Set 4 | samarai
# Processing Record 4 of Set 4 | umm lajj
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | kosai
# Processing Record 7 of Set 4 | cayenne
# Processing Record 8 of Set 4 | takanabe
# Processing Record 9 of Set 4 | ust-tsilma
# Processing Record 10 of Set 4 | lensk
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | wenling
# Processing Record 13 of Set 4 | kodiak
# Processing Record 14 of Set 4 | sharlyk
# Processing Record 15 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | olavarria
# Processing Record 18 of Set 4 | moron
# Processing Record 19 of Set 4 | kalevala
# Processing Record 20 of Set 4 | coahuayana
# Processing Record 21 of Set 4 | qaqortoq
# Processing Record 22 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 4 | bengkulu
# Processing Record 24 of Set 4 | marzuq
# Processing Record 25 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 4 | broken hill
# Processing Record 27 of Set 4 | skibotn
# Processing Record 28 of Set 4 | saint george
# Processing Record 29 of Set 4 | manutuke
# Processing Record 30 of Set 4 | la salle
# Processing Record 31 of Set 4 | oyama
# Processing Record 32 of Set 4 | bubaque
# Processing Record 33 of Set 4 | san vicente
# Processing Record 34 of Set 4 | inuvik
# Processing Record 35 of Set 4 | saldanha
# Processing Record 36 of Set 4 | ahipara
# Processing Record 37 of Set 4 | lalmanir hat
# City not found. Skipping...
# Processing Record 38 of Set 4 | nizhniy ingash
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | sturgeon falls
# Processing Record 41 of Set 4 | remanso
# Processing Record 42 of Set 4 | khorixas
# Processing Record 43 of Set 4 | pacasmayo
# Processing Record 44 of Set 4 | male
# Processing Record 45 of Set 4 | dunedin
# Processing Record 46 of Set 4 | pangody
# Processing Record 47 of Set 4 | polessk
# Processing Record 48 of Set 4 | leningradskiy
# Processing Record 49 of Set 4 | khorramabad
# Processing Record 50 of Set 4 | novotroitskaya
# Processing Record 1 of Set 5 | margate
# Processing Record 2 of Set 5 | norsup
# Processing Record 3 of Set 5 | narsaq
# Processing Record 4 of Set 5 | ridgecrest
# Processing Record 5 of Set 5 | ust-omchug
# Processing Record 6 of Set 5 | tonantins
# Processing Record 7 of Set 5 | faya
# Processing Record 8 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | clyde river
# Processing Record 11 of Set 5 | riwaka
# Processing Record 12 of Set 5 | axim
# Processing Record 13 of Set 5 | namtsy
# Processing Record 14 of Set 5 | saint-pierre
# Processing Record 15 of Set 5 | kittery
# Processing Record 16 of Set 5 | kahului
# Processing Record 17 of Set 5 | kikwit
# Processing Record 18 of Set 5 | santiago
# Processing Record 19 of Set 5 | sabha
# Processing Record 20 of Set 5 | bethel
# Processing Record 21 of Set 5 | rio gallegos
# Processing Record 22 of Set 5 | praia
# Processing Record 23 of Set 5 | helong
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | camacha
# Processing Record 26 of Set 5 | port hardy
# Processing Record 27 of Set 5 | atka
# City not found. Skipping...
# Processing Record 28 of Set 5 | berezovyy
# Processing Record 29 of Set 5 | yavaros
# Processing Record 30 of Set 5 | kapoeta
# Processing Record 31 of Set 5 | comodoro rivadavia
# Processing Record 32 of Set 5 | nortelandia
# Processing Record 33 of Set 5 | brae
# Processing Record 34 of Set 5 | kibala
# Processing Record 35 of Set 5 | parrsboro
# Processing Record 36 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 5 | lata
# Processing Record 38 of Set 5 | mizdah
# Processing Record 39 of Set 5 | kashira
# Processing Record 40 of Set 5 | korem
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | pokhara
# Processing Record 43 of Set 5 | lufkin
# Processing Record 44 of Set 5 | kanniyakumari
# Processing Record 45 of Set 5 | lasa
# Processing Record 46 of Set 5 | touros
# Processing Record 47 of Set 5 | vestmannaeyjar
# Processing Record 48 of Set 5 | saint-joseph
# Processing Record 49 of Set 5 | ardakan
# Processing Record 50 of Set 5 | upernavik
# Processing Record 1 of Set 6 | roald
# Processing Record 2 of Set 6 | salalah
# Processing Record 3 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 6 | baruun-urt
# Processing Record 5 of Set 6 | maragogi
# Processing Record 6 of Set 6 | beringovskiy
# Processing Record 7 of Set 6 | port elizabeth
# Processing Record 8 of Set 6 | crixas
# Processing Record 9 of Set 6 | iqaluit
# Processing Record 10 of Set 6 | lorengau
# Processing Record 11 of Set 6 | nacala
# Processing Record 12 of Set 6 | mathathane
# Processing Record 13 of Set 6 | broome
# Processing Record 14 of Set 6 | murray
# Processing Record 15 of Set 6 | vuktyl
# Processing Record 16 of Set 6 | dingle
# Processing Record 17 of Set 6 | mayo
# Processing Record 18 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 6 | zlitan
# Processing Record 20 of Set 6 | coquimbo
# Processing Record 21 of Set 6 | padang
# Processing Record 22 of Set 6 | tupik
# Processing Record 23 of Set 6 | luanda
# Processing Record 24 of Set 6 | florence
# Processing Record 25 of Set 6 | vila franca do campo
# Processing Record 26 of Set 6 | kualakapuas
# Processing Record 27 of Set 6 | sampit
# Processing Record 28 of Set 6 | bartica
# Processing Record 29 of Set 6 | port blair
# Processing Record 30 of Set 6 | tenango
# Processing Record 31 of Set 6 | lao cai
# Processing Record 32 of Set 6 | mar del plata
# Processing Record 33 of Set 6 | katobu
# Processing Record 34 of Set 6 | koslan
# Processing Record 35 of Set 6 | richards bay
# Processing Record 36 of Set 6 | klangenan
# Processing Record 37 of Set 6 | bom jesus da lapa
# Processing Record 38 of Set 6 | notodden
# Processing Record 39 of Set 6 | excelsior springs
# Processing Record 40 of Set 6 | sokoto
# Processing Record 41 of Set 6 | the valley
# Processing Record 42 of Set 6 | anar darreh
# City not found. Skipping...
# Processing Record 43 of Set 6 | aksarka
# Processing Record 44 of Set 6 | tutoia
# Processing Record 45 of Set 6 | las vegas
# Processing Record 46 of Set 6 | ixtapa
# Processing Record 47 of Set 6 | talnakh
# Processing Record 48 of Set 6 | mahina
# Processing Record 49 of Set 6 | la ronge
# Processing Record 50 of Set 6 | fruitvale
# Processing Record 1 of Set 7 | faanui
# Processing Record 2 of Set 7 | karratha
# Processing Record 3 of Set 7 | severodvinsk
# Processing Record 4 of Set 7 | fukue
# Processing Record 5 of Set 7 | aracuai
# Processing Record 6 of Set 7 | martapura
# Processing Record 7 of Set 7 | sakakah
# Processing Record 8 of Set 7 | dong hoi
# Processing Record 9 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 10 of Set 7 | mirnyy
# Processing Record 11 of Set 7 | gormi
# City not found. Skipping...
# Processing Record 12 of Set 7 | nome
# Processing Record 13 of Set 7 | lasem
# Processing Record 14 of Set 7 | caravelas
# Processing Record 15 of Set 7 | weyburn
# Processing Record 16 of Set 7 | puro
# Processing Record 17 of Set 7 | erzin
# Processing Record 18 of Set 7 | pisco
# Processing Record 19 of Set 7 | kalengwa
# Processing Record 20 of Set 7 | inhambane
# Processing Record 21 of Set 7 | muisne
# Processing Record 22 of Set 7 | constitucion
# Processing Record 23 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 7 | snasa
# Processing Record 25 of Set 7 | irbeyskoye
# Processing Record 26 of Set 7 | seredka
# Processing Record 27 of Set 7 | yaan
# Processing Record 28 of Set 7 | bredasdorp
# Processing Record 29 of Set 7 | lavrentiya
# Processing Record 30 of Set 7 | baie-comeau
# Processing Record 31 of Set 7 | simga
# Processing Record 32 of Set 7 | cazaje
# City not found. Skipping...
# Processing Record 33 of Set 7 | mumford
# Processing Record 34 of Set 7 | khatanga
# Processing Record 35 of Set 7 | belawan
# Processing Record 36 of Set 7 | saint-augustin
# Processing Record 37 of Set 7 | fortuna
# Processing Record 38 of Set 7 | januaria
# Processing Record 39 of Set 7 | bathsheba
# Processing Record 40 of Set 7 | airai
# Processing Record 41 of Set 7 | lonavale
# Processing Record 42 of Set 7 | half moon bay
# Processing Record 43 of Set 7 | tual
# Processing Record 44 of Set 7 | bykovo
# Processing Record 45 of Set 7 | bambous virieux
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | fort nelson
# Processing Record 48 of Set 7 | benguela
# Processing Record 49 of Set 7 | pimentel
# Processing Record 50 of Set 7 | lishui
# Processing Record 1 of Set 8 | acarau
# Processing Record 2 of Set 8 | lagoa
# Processing Record 3 of Set 8 | dawlatabad
# Processing Record 4 of Set 8 | beyneu
# Processing Record 5 of Set 8 | evans
# Processing Record 6 of Set 8 | minuri
# Processing Record 7 of Set 8 | waddan
# Processing Record 8 of Set 8 | zhigansk
# Processing Record 9 of Set 8 | luang prabang
# Processing Record 10 of Set 8 | meghri
# Processing Record 11 of Set 8 | nkhotakota
# Processing Record 12 of Set 8 | ostrovnoy
# Processing Record 13 of Set 8 | blyth
# Processing Record 14 of Set 8 | solec kujawski
# Processing Record 15 of Set 8 | auki
# Processing Record 16 of Set 8 | yerbogachen
# Processing Record 17 of Set 8 | rupert
# Processing Record 18 of Set 8 | aripuana
# Processing Record 19 of Set 8 | shetpe
# Processing Record 20 of Set 8 | mandalgovi
# Processing Record 21 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 22 of Set 8 | papara
# Processing Record 23 of Set 8 | vardo
# Processing Record 24 of Set 8 | raga
# Processing Record 25 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 8 | puerto quijarro
# Processing Record 27 of Set 8 | lazaro cardenas
# Processing Record 28 of Set 8 | kargat
# Processing Record 29 of Set 8 | turukhansk
# Processing Record 30 of Set 8 | cabedelo
# Processing Record 31 of Set 8 | noshiro
# Processing Record 32 of Set 8 | haines junction
# Processing Record 33 of Set 8 | longyearbyen
# Processing Record 34 of Set 8 | merauke
# Processing Record 35 of Set 8 | norman wells
# Processing Record 36 of Set 8 | spisska nova ves
# Processing Record 37 of Set 8 | teknaf
# Processing Record 38 of Set 8 | acapulco
# Processing Record 39 of Set 8 | nanortalik
# Processing Record 40 of Set 8 | nelson bay
# Processing Record 41 of Set 8 | urusha
# Processing Record 42 of Set 8 | erenhot
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | yar-sale
# Processing Record 45 of Set 8 | anadyr
# Processing Record 46 of Set 8 | panzhihua
# Processing Record 47 of Set 8 | aswan
# Processing Record 48 of Set 8 | wanaka
# Processing Record 49 of Set 8 | otjimbingwe
# Processing Record 50 of Set 8 | colares
# Processing Record 1 of Set 9 | havre-saint-pierre
# Processing Record 2 of Set 9 | namatanai
# Processing Record 3 of Set 9 | quelimane
# Processing Record 4 of Set 9 | chudniv
# Processing Record 5 of Set 9 | bell ville
# Processing Record 6 of Set 9 | malakal
# Processing Record 7 of Set 9 | oistins
# Processing Record 8 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 9 | muros
# Processing Record 10 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 11 of Set 9 | alofi
# Processing Record 12 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 9 | isiro
# Processing Record 14 of Set 9 | georgetown
# Processing Record 15 of Set 9 | sarwar
# Processing Record 16 of Set 9 | foki
# Processing Record 17 of Set 9 | de-kastri
# Processing Record 18 of Set 9 | rio grande
# Processing Record 19 of Set 9 | burns lake
# Processing Record 20 of Set 9 | rawson
# Processing Record 21 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 9 | desaguadero
# Processing Record 23 of Set 9 | kalmunai
# Processing Record 24 of Set 9 | northam
# Processing Record 25 of Set 9 | aklavik
# Processing Record 26 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 9 | batemans bay
# Processing Record 28 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 29 of Set 9 | vostok
# Processing Record 30 of Set 9 | businga
# Processing Record 31 of Set 9 | komsomolskiy
# Processing Record 32 of Set 9 | nikki
# Processing Record 33 of Set 9 | barinitas
# Processing Record 34 of Set 9 | puntarenas
# Processing Record 35 of Set 9 | grindavik
# Processing Record 36 of Set 9 | grenada
# Processing Record 37 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 9 | urumqi
# Processing Record 39 of Set 9 | port lincoln
# Processing Record 40 of Set 9 | zolotonosha
# Processing Record 41 of Set 9 | qarqin
# Processing Record 42 of Set 9 | bratsk
# Processing Record 43 of Set 9 | wembley
# Processing Record 44 of Set 9 | anloga
# Processing Record 45 of Set 9 | comal
# Processing Record 46 of Set 9 | warrensburg
# Processing Record 47 of Set 9 | kommunar
# Processing Record 48 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 49 of Set 9 | wanning
# Processing Record 50 of Set 9 | poltavka
# Processing Record 1 of Set 10 | kavaratti
# Processing Record 2 of Set 10 | marawi
# Processing Record 3 of Set 10 | darhan
# Processing Record 4 of Set 10 | pacific grove
# Processing Record 5 of Set 10 | grimma
# Processing Record 6 of Set 10 | celestun
# Processing Record 7 of Set 10 | rochegda
# Processing Record 8 of Set 10 | of
# City not found. Skipping...
# Processing Record 9 of Set 10 | usinsk
# Processing Record 10 of Set 10 | pavda
# City not found. Skipping...
# Processing Record 11 of Set 10 | abu dhabi
# Processing Record 12 of Set 10 | kangaatsiaq
# Processing Record 13 of Set 10 | hami
# Processing Record 14 of Set 10 | akhtubinsk
# Processing Record 15 of Set 10 | mao
# Processing Record 16 of Set 10 | stephenville
# Processing Record 17 of Set 10 | laguna
# Processing Record 18 of Set 10 | zakamensk
# Processing Record 19 of Set 10 | smithers
# Processing Record 20 of Set 10 | kalianget
# Processing Record 21 of Set 10 | shubarshi
# Processing Record 22 of Set 10 | sao bernardo
# Processing Record 23 of Set 10 | taoudenni
# Processing Record 24 of Set 10 | loreto
# Processing Record 25 of Set 10 | honningsvag
# Processing Record 26 of Set 10 | ouargaye
# Processing Record 27 of Set 10 | conakry
# Processing Record 28 of Set 10 | lappeenranta
# Processing Record 29 of Set 10 | puerto maldonado
# Processing Record 30 of Set 10 | tabas
# Processing Record 31 of Set 10 | labuhan
# Processing Record 32 of Set 10 | los algarrobos
# Processing Record 33 of Set 10 | mae chan
# Processing Record 34 of Set 10 | dukat
# Processing Record 35 of Set 10 | teneguiban
# City not found. Skipping...
# Processing Record 36 of Set 10 | ashland
# Processing Record 37 of Set 10 | kavieng
# Processing Record 38 of Set 10 | sur
# Processing Record 39 of Set 10 | derzhavinsk
# Processing Record 40 of Set 10 | baska
# Processing Record 41 of Set 10 | herat
# Processing Record 42 of Set 10 | tuatapere
# Processing Record 43 of Set 10 | aksu
# Processing Record 44 of Set 10 | ramhormoz
# Processing Record 45 of Set 10 | micheweni
# Processing Record 46 of Set 10 | kenai
# Processing Record 47 of Set 10 | nouakchott
# Processing Record 48 of Set 10 | quatre cocos
# Processing Record 49 of Set 10 | bin qirdan
# Processing Record 50 of Set 10 | paragominas
# Processing Record 1 of Set 11 | bichura
# Processing Record 2 of Set 11 | bom jardim
# Processing Record 3 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 4 of Set 11 | hay river
# Processing Record 5 of Set 11 | phek
# Processing Record 6 of Set 11 | sola
# Processing Record 7 of Set 11 | lukovetskiy
# Processing Record 8 of Set 11 | yarmouth
# Processing Record 9 of Set 11 | kirakira
# Processing Record 10 of Set 11 | bima
# Processing Record 11 of Set 11 | hokitika
# Processing Record 12 of Set 11 | guadalupe y calvo
# Processing Record 13 of Set 11 | statesville
# Processing Record 14 of Set 11 | karoi
# Processing Record 15 of Set 11 | koboko
# Processing Record 16 of Set 11 | tynda
# Processing Record 17 of Set 11 | carutapera
# Processing Record 18 of Set 11 | prince rupert
# Processing Record 19 of Set 11 | luwuk
# Processing Record 20 of Set 11 | acandi
# Processing Record 21 of Set 11 | rio cuarto
# Processing Record 22 of Set 11 | mnogovershinnyy
# Processing Record 23 of Set 11 | fort-shevchenko
# Processing Record 24 of Set 11 | novoseleznevo
# Processing Record 25 of Set 11 | tierra blanca
# Processing Record 26 of Set 11 | atotonilco el alto
# Processing Record 27 of Set 11 | arivonimamo
# Processing Record 28 of Set 11 | bajil
# Processing Record 29 of Set 11 | verkhnyaya inta
# Processing Record 30 of Set 11 | yuksekova
# Processing Record 31 of Set 11 | oum hadjer
# Processing Record 32 of Set 11 | cape coast
# Processing Record 33 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 11 | becerril
# Processing Record 35 of Set 11 | kodinsk
# Processing Record 36 of Set 11 | athabasca
# Processing Record 37 of Set 11 | ziro
# Processing Record 38 of Set 11 | lukulu
# Processing Record 39 of Set 11 | diego de almagro
# Processing Record 40 of Set 11 | abu kamal
# Processing Record 41 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 42 of Set 11 | tongling
# Processing Record 43 of Set 11 | mustafakemalpasa
# Processing Record 44 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 11 | angoche
# Processing Record 46 of Set 11 | san juan
# Processing Record 47 of Set 11 | yichang
# Processing Record 48 of Set 11 | rabo de peixe
# Processing Record 49 of Set 11 | odoreu
# Processing Record 50 of Set 11 | shieli
# Processing Record 1 of Set 12 | mapimi
# Processing Record 2 of Set 12 | labuan
# Processing Record 3 of Set 12 | hovd
# Processing Record 4 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 12 | belaya gora
# Processing Record 6 of Set 12 | morondava
# Processing Record 7 of Set 12 | xuddur
# Processing Record 8 of Set 12 | launceston
# Processing Record 9 of Set 12 | salekhard
# Processing Record 10 of Set 12 | chifeng
# Processing Record 11 of Set 12 | awallan
# Processing Record 12 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 13 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 12 | katsuura
# Processing Record 15 of Set 12 | darab
# Processing Record 16 of Set 12 | warrnambool
# Processing Record 17 of Set 12 | dauphin
# Processing Record 18 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 12 | sitio novo do tocantins
# Processing Record 20 of Set 12 | ust-tarka
# Processing Record 21 of Set 12 | kirensk
# Processing Record 22 of Set 12 | tura
# Processing Record 23 of Set 12 | gigmoto
# Processing Record 24 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 12 | college
# Processing Record 26 of Set 12 | zemio
# Processing Record 27 of Set 12 | avera
# Processing Record 28 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 12 | noumea
# Processing Record 30 of Set 12 | bardiyah
# Processing Record 31 of Set 12 | manoel urbano
# Processing Record 32 of Set 12 | nikolayevsk-na-amure
# Processing Record 33 of Set 12 | bandarbeyla
# Processing Record 34 of Set 12 | aketi
# Processing Record 35 of Set 12 | jining
# Processing Record 36 of Set 12 | marau
# Processing Record 37 of Set 12 | eureka
# Processing Record 38 of Set 12 | port hawkesbury
# Processing Record 39 of Set 12 | dali
# Processing Record 40 of Set 12 | nizhnyaya maktama
# Processing Record 41 of Set 12 | pemba
# Processing Record 42 of Set 12 | korfovskiy
# Processing Record 43 of Set 12 | miyako
# Processing Record 44 of Set 12 | langxiang
# Processing Record 45 of Set 12 | surab
# Processing Record 46 of Set 12 | juneau
# Processing Record 47 of Set 12 | namibe
# Processing Record 48 of Set 12 | loviisa
# Processing Record 49 of Set 12 | muli
# Processing Record 50 of Set 12 | olden
# Processing Record 1 of Set 13 | caborca
# Processing Record 2 of Set 13 | el vigia
# Processing Record 3 of Set 13 | mananjary
# Processing Record 4 of Set 13 | burica
# City not found. Skipping...
# Processing Record 5 of Set 13 | lambarene
# Processing Record 6 of Set 13 | port macquarie
# Processing Record 7 of Set 13 | sarangani
# Processing Record 8 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 13 | lawrenceburg
# Processing Record 10 of Set 13 | belen
# Processing Record 11 of Set 13 | ketchikan
# Processing Record 12 of Set 13 | lakewood
# Processing Record 13 of Set 13 | havelock
# Processing Record 14 of Set 13 | codrington
# Processing Record 15 of Set 13 | vrangel
# Processing Record 16 of Set 13 | marsh harbour
# Processing Record 17 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 13 | shiliguri
# Processing Record 19 of Set 13 | port augusta
# Processing Record 20 of Set 13 | pathein
# Processing Record 21 of Set 13 | waipawa
# Processing Record 22 of Set 13 | tanout
# Processing Record 23 of Set 13 | kushmurun
# Processing Record 24 of Set 13 | tamworth
# Processing Record 25 of Set 13 | pecs
# Processing Record 26 of Set 13 | eyl
# Processing Record 27 of Set 13 | itarema
# Processing Record 28 of Set 13 | vila velha
# Processing Record 29 of Set 13 | gemena
# Processing Record 30 of Set 13 | saint-georges
# Processing Record 31 of Set 13 | keti bandar
# Processing Record 32 of Set 13 | bosaso
# Processing Record 33 of Set 13 | sumenep
# Processing Record 34 of Set 13 | bogo
# Processing Record 35 of Set 13 | cambridge
# Processing Record 36 of Set 13 | key west
# Processing Record 37 of Set 13 | catuday
# Processing Record 38 of Set 13 | nara
# Processing Record 39 of Set 13 | wajima
# Processing Record 40 of Set 13 | san quintin
# Processing Record 41 of Set 13 | arrifes
# Processing Record 42 of Set 13 | benghazi
# Processing Record 43 of Set 13 | coihaique
# Processing Record 44 of Set 13 | asau
# Processing Record 45 of Set 13 | ouesso
# Processing Record 46 of Set 13 | hambantota
# Processing Record 47 of Set 13 | impfondo
# Processing Record 48 of Set 13 | nago
# Processing Record 49 of Set 13 | honolulu
# Processing Record 50 of Set 13 | jamame
# Processing Record 1 of Set 14 | pineville
# Processing Record 2 of Set 14 | omboue
# Processing Record 3 of Set 14 | lalibela
# Processing Record 4 of Set 14 | hanna
# Processing Record 5 of Set 14 | paidha
# Processing Record 6 of Set 14 | guerrero negro
# Processing Record 7 of Set 14 | kaeo
# Processing Record 8 of Set 14 | porosozero
# Processing Record 9 of Set 14 | kulhudhuffushi
# Processing Record 10 of Set 14 | kashi
# Processing Record 11 of Set 14 | chaochou
# City not found. Skipping...
# Processing Record 12 of Set 14 | mahanoro
# Processing Record 13 of Set 14 | klaksvik
# Processing Record 14 of Set 14 | pitimbu
# Processing Record 15 of Set 14 | hasaki
# Processing Record 16 of Set 14 | mezen
# Processing Record 17 of Set 14 | svetlogorsk
# Processing Record 18 of Set 14 | mehamn
# Processing Record 19 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 20 of Set 14 | oranjestad
# Processing Record 21 of Set 14 | zhezkazgan
# Processing Record 22 of Set 14 | alice springs
# Processing Record 23 of Set 14 | zwedru
# Processing Record 24 of Set 14 | naila
# Processing Record 25 of Set 14 | fare
# Processing Record 26 of Set 14 | nizhnyaya tavda
# Processing Record 27 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 14 | guayabal
# Processing Record 29 of Set 14 | islamkot
# Processing Record 30 of Set 14 | gizo
# Processing Record 31 of Set 14 | jasper
# Processing Record 32 of Set 14 | araouane
# Processing Record 33 of Set 14 | mathbaria
# Processing Record 34 of Set 14 | ilhabela
# Processing Record 35 of Set 14 | betsiamites
# Processing Record 36 of Set 14 | daru
# Processing Record 37 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 14 | nouadhibou
# Processing Record 39 of Set 14 | agadir
# Processing Record 40 of Set 14 | najran
# Processing Record 41 of Set 14 | la rioja
# Processing Record 42 of Set 14 | mount gambier
# Processing Record 43 of Set 14 | mount darwin
# Processing Record 44 of Set 14 | hvolsvollur
# Processing Record 45 of Set 14 | teya
# Processing Record 46 of Set 14 | hofn
# Processing Record 47 of Set 14 | nemuro
# Processing Record 48 of Set 14 | sungurlu
# Processing Record 49 of Set 14 | leua
# Processing Record 50 of Set 14 | tshikapa
# Processing Record 1 of Set 15 | samfya
# Processing Record 2 of Set 15 | kotaparh
# Processing Record 3 of Set 15 | miri
# Processing Record 4 of Set 15 | florianopolis
# Processing Record 5 of Set 15 | alghero
# Processing Record 6 of Set 15 | buchanan
# Processing Record 7 of Set 15 | shushtar
# Processing Record 8 of Set 15 | podgornoye
# Processing Record 9 of Set 15 | novobirilyussy
# Processing Record 10 of Set 15 | urubicha
# Processing Record 11 of Set 15 | miramar
# Processing Record 12 of Set 15 | kidal
# Processing Record 13 of Set 15 | matara
# Processing Record 14 of Set 15 | jingdezhen
# Processing Record 15 of Set 15 | ukiah
# Processing Record 16 of Set 15 | roma
# Processing Record 17 of Set 15 | anlu
# Processing Record 18 of Set 15 | shingu
# Processing Record 19 of Set 15 | adre
# Processing Record 20 of Set 15 | minot
# Processing Record 21 of Set 15 | henties bay
# Processing Record 22 of Set 15 | paamiut
# Processing Record 23 of Set 15 | basco
# Processing Record 24 of Set 15 | zatoka
# Processing Record 25 of Set 15 | murray bridge
# Processing Record 26 of Set 15 | kudahuvadhoo
# Processing Record 27 of Set 15 | healdsburg
# Processing Record 28 of Set 15 | yokadouma
# Processing Record 29 of Set 15 | muscat
# Processing Record 30 of Set 15 | kanepi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 670

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Biak  -0.9131  122.8766     77.43        84          93
# 1            Chuy -33.6971  -53.4616     64.99        55           3
# 2            Uray  60.1247   64.7758     60.57        69         100
# 3  Cabo San Lucas  22.8909 -109.9124     79.52        52         100
# 4           Arlit  18.7369    7.3853     91.47        11          44
# 5  Ribeira Grande  38.5167  -28.7000     63.00        72          40
# 6         Ushuaia -54.8000  -68.3000     49.62        76          75
# 7        Urubamba -13.3047  -72.1158     65.30        69          89
# 8     New Norfolk -42.7826  147.0587     42.30        88          13
# 9   Cockburn Town  21.4612  -71.1419     80.76        75          97
#
#    Wind Speed Country Current Description
# 0        5.53      ID     overcast clouds
# 1        8.23      UY           clear sky
# 2        6.02      RU          light rain
# 3        8.05      MX     overcast clouds
# 4        1.88      NE    scattered clouds
# 5       19.57      PT    scattered clouds
# 6       20.71      AR       broken clouds
# 7        5.95      PE     overcast clouds
# 8        2.59      AU          few clouds
# 9        9.89      TC     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]


# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Biak      ID  -0.9131  122.8766     77.43        84          93
# 1            Chuy      UY -33.6971  -53.4616     64.99        55           3
# 2            Uray      RU  60.1247   64.7758     60.57        69         100
# 3  Cabo San Lucas      MX  22.8909 -109.9124     79.52        52         100
# 4           Arlit      NE  18.7369    7.3853     91.47        11          44
# 5  Ribeira Grande      PT  38.5167  -28.7000     63.00        72          40
# 6         Ushuaia      AR -54.8000  -68.3000     49.62        76          75
# 7        Urubamba      PE -13.3047  -72.1158     65.30        69          89
# 8     New Norfolk      AU -42.7826  147.0587     42.30        88          13
# 9   Cockburn Town      TC  21.4612  -71.1419     80.76        75          97
#
#    Wind Speed Current Description
# 0        5.53     overcast clouds
# 1        8.23           clear sky
# 2        6.02          light rain
# 3        8.05     overcast clouds
# 4        1.88    scattered clouds
# 5       19.57    scattered clouds
# 6       20.71       broken clouds
# 7        5.95     overcast clouds
# 8        2.59          few clouds
# 9        9.89     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
